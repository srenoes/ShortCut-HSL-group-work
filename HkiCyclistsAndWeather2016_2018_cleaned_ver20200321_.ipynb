# %% [markdown]
# PLAYING WITH 1ST COMBINED DATASET

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('HkiCyclistsandWeather_2016_2018_ver20200324.csv')

# What has to be done for e.g. Month, Year, Rush Hours, Weekend, Morning/evening

# %%
df.head()
# where does the "Unnamed: 0" come from?
# Out:
#    Unnamed: 0        Date   Time Weekday  RelativeHumidity(%)  \
# 0           0  2016-01-01  00:00     Fri                 81.0
# 1           1  2016-01-01  01:00     Fri                 78.0
# 2           2  2016-01-01  02:00     Fri                 78.0
# 3           3  2016-01-01  03:00     Fri                 78.0
# 4           4  2016-01-01  04:00     Fri                 76.0
#
#    AirTemperature(degC)  SnowDepth(cm)  WindSpeed(m/s)  WindDirection(deg)  \
# 0                  -3.5            0.0             4.3               164.0
# 1                  -3.5            0.0             4.1               144.0
# 2                  -3.3            0.0             5.0               173.0
# 3                  -3.0            0.0             3.9               147.0
# 4                  -3.5            0.0             3.4               144.0
#
#    Auroransilta  ...  Merikannontie  Munkkiniemi bridge south side  \
# 0           NaN  ...            2.0                            3.0
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date   Time Weekday  RelativeHumidity(%)  \
# 26300       26300  2018-12-31  20:00     Mon                 91.0
# 26301       26301  2018-12-31  21:00     Mon                 88.0
# 26302       26302  2018-12-31  22:00     Mon                 95.0
# 26303       26303  2018-12-31  23:00     Mon                 95.0
# 26304       26304  2019-01-01  00:00     NaN                 94.0
#
#        AirTemperature(degC)  SnowDepth(cm)  WindSpeed(m/s)  \
# 26300                   1.0            0.0             8.8
# 26301                   1.3            0.0             9.5
# 26302                   0.8            0.0             7.6
# 26303                   1.1            2.0             8.6
# 26304                   1.4            2.0             8.4
#
#        WindDirection(deg)  Auroransilta  ...  Merikannontie  \
# 26300               207.0           1.0  ...            2.0
# 26301               207.0           1.0  ...            7.0
# ...

# %%
#Set Indexes
#df = df.set_index(['Date','Time'])
#df.head()

# %%
df.info()
# a lot of missing data in Auroransilta, Kaivokatu, Kapyla pohjois..., Viikintie, LAuttasaari North
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 29 columns):
# Unnamed: 0                        26305 non-null int64
# Date                              26305 non-null object
# Time                              26305 non-null object
# Weekday                           26304 non-null object
# RelativeHumidity(%)               26274 non-null float64
# AirTemperature(degC)              26303 non-null float64
# SnowDepth(cm)                     26221 non-null float64
# WindSpeed(m/s)                    26069 non-null float64
# WindDirection(deg)                26070 non-null float64
# Auroransilta                      10010 non-null float64
# Etelaesplanadi                    26280 non-null float64
# Huopalahti (station)              26304 non-null float64
# Kaisaniemi/Elaintarhanlahti       26304 non-null float64
# Kaivokatu                         10008 non-null float64
# Kulosaari bridge south            26304 non-null float64
# ...

# %%
df = df.drop(['Unnamed: 0','Auroransilta', 'Kaivokatu', 'Kapyla, Pohjoisbaana', 'Lauttasaari bridge north side', 'Viikintie'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 23 columns):
# Date                              26305 non-null object
# Time                              26305 non-null object
# Weekday                           26304 non-null object
# RelativeHumidity(%)               26274 non-null float64
# AirTemperature(degC)              26303 non-null float64
# SnowDepth(cm)                     26221 non-null float64
# WindSpeed(m/s)                    26069 non-null float64
# WindDirection(deg)                26070 non-null float64
# Etelaesplanadi                    26280 non-null float64
# Huopalahti (station)              26304 non-null float64
# Kaisaniemi/Elaintarhanlahti       26304 non-null float64
# Kulosaari bridge south            26304 non-null float64
# Kulosaaren silta po.              26304 non-null float64
# Kuusisaarentie                    26304 non-null float64
# Lauttasaarin bridge south side    26304 non-null float64
# ...

# %%
# Snow depth corrections
# case['location'] = np.where(case.prov_state.isnull(), case.country, case.prov_state)
df['SnowDepth(cm)'] = np.where(df['SnowDepth(cm)'].isnull(), 0.0, df['SnowDepth(cm)'])
df.loc[273:325,'SnowDepth(cm)'] = 23.0
df.loc[425:427,'SnowDepth(cm)'] = 22.0
df.loc[560:622,'SnowDepth(cm)'] = 22.0
df.loc[19151:19211,'SnowDepth(cm)'] = 23.0
df.loc[19742:19761,'SnowDepth(cm)'] = 23.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 24 columns):
# index                             26305 non-null int64
# Date                              26305 non-null object
# Time                              26305 non-null object
# Weekday                           26304 non-null object
# RelativeHumidity(%)               26274 non-null float64
# AirTemperature(degC)              26303 non-null float64
# SnowDepth(cm)                     26305 non-null float64
# WindSpeed(m/s)                    26069 non-null float64
# WindDirection(deg)                26070 non-null float64
# Etelaesplanadi                    26280 non-null float64
# Huopalahti (station)              26304 non-null float64
# Kaisaniemi/Elaintarhanlahti       26304 non-null float64
# Kulosaari bridge south            26304 non-null float64
# Kulosaaren silta po.              26304 non-null float64
# Kuusisaarentie                    26304 non-null float64
# ...

# %%
df.describe()
# Out:
#               index  RelativeHumidity(%)  AirTemperature(degC)  SnowDepth(cm)  \
# count  26305.000000         26274.000000          26303.000000   26305.000000
# mean   13152.000000            78.844104              6.890195       1.609580
# std     7593.743752            15.633415              8.725958       5.309879
# min        0.000000            19.000000            -23.800000      -1.000000
# 25%     6576.000000            70.000000              0.700000      -1.000000
# 50%    13152.000000            83.000000              6.000000       0.000000
# 75%    19728.000000            91.000000             14.300000       0.000000
# max    26304.000000           100.000000             30.200000      23.000000
#
#        WindSpeed(m/s)  WindDirection(deg)  Etelaesplanadi  \
# count    26069.000000        26070.000000    26280.000000
# mean         3.491699          201.141082       52.157953
# std          1.575847          100.700415       68.488112
# ...

# %%
# [[Etelaesplanadi',
#       'Huopalahti (station)', 'Kaisaniemi/Elaintarhanlahti',
 #      'Kulosaari bridge south', 'Kulosaaren silta po. ', 'Kuusisaarentie',
  #     'Lauttasaarin bridge south side',
   #    'Merikannontie', 'Munkkiniemi bridge south side',
    #   'Munkkiniemi bridge north side', 'Heperia park/Ooppera',
     #  'Pitkasilta itapuoli', 'Pitkasilta west side',
      #  'Ratapihantie', 'Baana']]

# %%
samplea = df[['AirTemperature(degC)', 'RelativeHumidity(%)','WindSpeed(m/s)','Etelaesplanadi', 'Kuusisaarentie','Merikannontie','Ratapihantie', 'Baana']]
samplea.head()
# Out:
#    AirTemperature(degC)  RelativeHumidity(%)  WindSpeed(m/s)  Etelaesplanadi  \
# 0                  -3.5                 81.0             4.3            12.0
# 1                  -3.5                 78.0             4.1             3.0
# 2                  -3.3                 78.0             5.0             5.0
# 3                  -3.0                 78.0             3.9             3.0
# 4                  -3.5                 76.0             3.4             3.0
#
#    Kuusisaarentie  Merikannontie  Ratapihantie  Baana
# 0             1.0            2.0           2.0    6.0
# 1             0.0            1.0          10.0    5.0
# 2             0.0            2.0           2.0    5.0
# 3             1.0            1.0           7.0    3.0
# 4             1.0            3.0           1.0    3.0

# %%
#sns.pairplot(samplea)

# %%
#sns.set(rc={'figure.figsize':(11.7,8.27)})
#sns.barplot(data=samplea)

# %%
# reset index
df = df.reset_index()
df.head()
# Out:
#    level_0  index        Date   Time Weekday  RelativeHumidity(%)  \
# 0        0      0  2016-01-01  00:00     Fri                 81.0
# 1        1      1  2016-01-01  01:00     Fri                 78.0
# 2        2      2  2016-01-01  02:00     Fri                 78.0
# 3        3      3  2016-01-01  03:00     Fri                 78.0
# 4        4      4  2016-01-01  04:00     Fri                 76.0
#
#    AirTemperature(degC)  SnowDepth(cm)  WindSpeed(m/s)  WindDirection(deg)  \
# 0                  -3.5            0.0             4.3               164.0
# 1                  -3.5            0.0             4.1               144.0
# 2                  -3.3            0.0             5.0               173.0
# 3                  -3.0            0.0             3.9               147.0
# 4                  -3.5            0.0             3.4               144.0
#
#    ...  Kuusisaarentie  Lauttasaarin bridge south side  Merikannontie  \
# ...

# %%
#sns.boxplot(x='Etelaesplanadi', data = samplea)
#sns.boxplot(data = samplea)

# %%
#sns.lineplot()

# %%
df.to_csv('HkiCyclistsandWeather_2016_2018_cleaned_ver20200324.csv')
