# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import datetime

# %%
VANTAA_Bikers=pd.read_csv('VantaaBikers_cleanDataset.csv')
VANTAA_Bikers.Date=pd.to_datetime(VANTAA_Bikers.Date,format='%Y-%m-%d')
VANTAA_Bikers=VANTAA_Bikers.set_index(['Date','Time'])
cindex_VANTAA=VANTAA_Bikers.columns[1:]
#VANTAA_Bikers.info()

ESPOO_Bikers=pd.read_csv('EspooBikers_cleanDataset.csv')
ESPOO_Bikers.Date=pd.to_datetime(ESPOO_Bikers.Date,format='%Y-%m-%d')
ESPOO_Bikers=ESPOO_Bikers.set_index(['Date','Time'])
cindex_ESPOO=ESPOO_Bikers.columns[1:]
#ESPOO_Bikers.info()

HELSINKI_Bikers=pd.read_csv('HelsinkiBikers_cleanDataset.csv')
HELSINKI_Bikers.Date=pd.to_datetime(HELSINKI_Bikers.Date,format='%Y-%m-%d')
HELSINKI_Bikers=HELSINKI_Bikers.set_index(['Date','Time'])
HELSINKI_Bikers.Baana=HELSINKI_Bikers.Baana*1.0
cindex_HELSINKI=HELSINKI_Bikers.columns[1:]

#HELSINKI_Bikers.info()

ALL_Bikers=HELSINKI_Bikers.copy()
ALL_Bikers=ALL_Bikers.join(VANTAA_Bikers.iloc[:,1:],how='left')
ALL_Bikers=ALL_Bikers.join(ESPOO_Bikers.iloc[:,1:],how='left')
#ALL_Bikers.info()


pyhapaivat=pd.DataFrame();
for vuosi in range(2014,2020):
    table=pd.read_html(f'https://www.webcal.fi/fi-FI/pyhat.php?y={vuosi}')
    table=table[0].iloc[:,1:4]
    table.iloc[:,2]=pd.to_datetime(table.iloc[:,2], format='%d.%m.%Y', errors='coerce')
    table.columns=['Pyhapaiva','Viikonpaiva',str(vuosi)]
    table=table.drop('Viikonpaiva',axis=1).set_index('Pyhapaiva')    
    if vuosi==2014:
        pyhapaivat=table
    else:
        pyhapaivat=pyhapaivat.join(table)

pyhapaivat_list=[date for date in pd.DatetimeIndex(pyhapaivat.iloc[:,0]).date]
for n in range(1,6):
    pyhapaivat_list.extend([date for date in pd.DatetimeIndex(pyhapaivat.iloc[:,n]).date])
pyhapaivat_set=set(pyhapaivat_list)

def onko_pyhapaiva(pdf):
    return (np.array([date in pyhapaivat_set for date in pd.DatetimeIndex(pdf.index).date]))



month_list=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

ALL_Bikers['pyhapaiva']=onko_pyhapaiva(ALL_Bikers.reset_index().set_index('Date'))
ALL_Bikers['month']=np.array([month_list[month-1] for month in pd.DatetimeIndex(ALL_Bikers.reset_index()['Date']).month])
ALL_Bikers['year']=pd.DatetimeIndex(ALL_Bikers.reset_index()['Date']).year


ALL_Bikers['nData']=ALL_Bikers.iloc[:,1:-1].T.count().astype('Int64')
ALL_Bikers['nData_VAN']=ALL_Bikers.loc[:,cindex_VANTAA].T.count().astype('Int64')
ALL_Bikers['nData_ESP']=ALL_Bikers.loc[:,cindex_ESPOO].T.count().astype('Int64')
ALL_Bikers['nData_HEL']=ALL_Bikers.loc[:,cindex_HELSINKI].T.count().astype('Int64')

#ALL_Bikers


columns=ALL_Bikers.columns
columns=columns[0:1].append(columns[-7:]).append(columns[1:-7])
columns
ALL_Bikers=ALL_Bikers.reindex(columns=columns)

ALL_Bikers=ALL_Bikers.reset_index()
ALL_Bikers.to_csv('All_bikers.csv',index=False)
ALL_Bikers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51216 entries, 0 to 51215
# Data columns (total 94 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Date                                           51216 non-null  datetime64[ns]
#  1   Time                                           51216 non-null  object
#  2   Weekday                                        51216 non-null  object
#  3   pyhapaiva                                      51216 non-null  bool
#  4   month                                          51216 non-null  object
#  5   year                                           51216 non-null  int64
#  6   nData                                          51216 non-null  Int64
#  7   nData_VAN                                      51216 non-null  Int64
#  8   nData_ESP                                      51216 non-null  Int64
#  9   nData_HEL                                      51216 non-null  Int64
#  10  Auroransilta                                   17330 non-null  float64
#  11  Etelaesplanadi                                 50546 non-null  float64
#  12  Huopalahti (station)                           39431 non-null  float64
#  13  Kaisaniemi/Elaintarhanlahti                    51214 non-null  float64
#  14  Kaivokatu                                      17328 non-null  float64
#  15  Kulosaari bridge south                         39431 non-null  float64
#  16  Kulosaaren silta po.                           39431 non-null  float64
#  17  Kuusisaarentie                                 39431 non-null  float64
#  18  Kapyla, Pohjoisbaana                           18486 non-null  float64
#  19  Lauttasaarin bridge south side                 44326 non-null  float64
#  20  Merikannontie                                  44326 non-null  float64
#  21  Munkkiniemi bridge south side                  50911 non-null  float64
#  22  Munkkiniemi bridge north side                  51214 non-null  float64
#  23  Heperia park/Ooppera                           50038 non-null  float64
#  24  Pitkasilta itapuoli                            44326 non-null  float64
#  25  Pitkasilta west side                           51214 non-null  float64
#  26  Lauttasaari bridge north side                  40206 non-null  float64
#  27  Ratapihantie                                   39431 non-null  float64
#  28  Viikintie                                      10514 non-null  float64
#  29  Baana                                          51216 non-null  float64
#  30  Asolanvayla P                                  3605 non-null   float64
#  31  Asolanvayla E                                  2981 non-null   float64
#  32  Hakunilantie P                                 3687 non-null   float64
#  33  Hakunilantie E                                 3355 non-null   float64
#  34  Kyytitie I                                     4272 non-null   float64
#  35  Kyytitie L                                     4272 non-null   float64
#  36  Kaislaranta P                                  12678 non-null  float64
#  37  Kaislaranta E                                  12443 non-null  float64
#  38  Kuusijarvi P                                   1496 non-null   float64
#  39  Kuusijarvi E                                   3877 non-null   float64
#  40  Kytopuisto P                                   12429 non-null  float64
#  41  Kytöpuisto E                                   12429 non-null  float64
#  42  Pellas I                                       2828 non-null   float64
#  43  Pellas L                                       2828 non-null   float64
#  44  Simonkylantie P                                3562 non-null   float64
#  45  Simonkylantie E                                3562 non-null   float64
#  46  Solkikuja I                                    3623 non-null   float64
#  47  Solkikuja L                                    3623 non-null   float64
#  48  Vanha Porvoontie P                             3586 non-null   float64
#  49  Vanha Porvoontie E                             3586 non-null   float64
#  50  Vantaanlaaksontie P                            2917 non-null   float64
#  51  Vantaanlaaksontie E                            2917 non-null   float64
#  52  Ylastontie I                                   3247 non-null   float64
#  53  Ylastontie L                                   3247 non-null   float64
#  54  Espoon portti (Eco-Counter)                    7940 non-null   float64
#  55  Espoonlahdenraitti (Eco-Counter)               8786 non-null   float64
#  56  Gallen-Kallela (Eco-Counter)                   7926 non-null   float64
#  57  Gallen-Kallelan tie (DSL10)                    3400 non-null   float64
#  58  Haukilahti (Viacount)                          168 non-null    float64
#  59  Kalevalantien alikulku (DSL10)                 17856 non-null  float64
#  60  Keha I, Laajalahti (DSL10)                     18488 non-null  float64
#  61  Keha I, Laajalahti (Eco-counter)               7922 non-null   float64
#  62  Keilaniemi, Keilaterassi (Viacount)            168 non-null    float64
#  63  Keskuspuisto, etelahaara, ita (Viacount 2)     168 non-null    float64
#  64  Keskuspuisto, etelahaara, lansi (Viacount 2)   168 non-null    float64
#  65  Keskuspuisto, Grimangen (Viacount 2)           168 non-null    float64
#  66  Keskuspuisto, Mossenkar (Viacount 2)           168 non-null    float64
#  67  Kiltapolku (Viacount 2)                        144 non-null    float64
#  68  Kiltaraitti, etela (Viacount 2)                144 non-null    float64
#  69  Kiltaraitti, pohjoinen (Viacount 2)            168 non-null    float64
#  70  Kirkkojarventie (DSL10)                        16494 non-null  float64
#  71  Kivenlahden uimaranta (Viacount)               168 non-null    float64
#  72  Kivenlahti (Viacount)                          168 non-null    float64
#  73  Lansivayla (Eco-counter)                       7931 non-null   float64
#  74  Lansivayla, Karhusaari (DSL10)                 17887 non-null  float64
#  75  Martinsillantie (DSL10)                        16285 non-null  float64
#  76  Merituulentie (DSL10)                          7408 non-null   float64
#  77  Olarinkatu (Eco-Counter)                       8236 non-null   float64
#  78  Otaniemi, Otaranta (Viacount)                  168 non-null    float64
#  79  Pitkajarventie (DSL10)                         17702 non-null  float64
#  80  Pohjantien ylikulku (DSL10)                    12865 non-null  float64
#  81  Pohjantien ylikulku (Eco-Counter)              16478 non-null  float64
#  82  Pohjantien ylikulku (Viacount 2)               168 non-null    float64
#  83  Paivankestamonpolku, Kera (Eco-Counter)        7927 non-null   float64
#  84  Rantaradanraitti, Helsingin raja (Viacount 2)  503 non-null    float64
#  85  Soukka (Viacount)                              168 non-null    float64
#  86  Suomenlahdentie (Eco-Counter)                  7926 non-null   float64
#  87  Suomenlahdentie, etelainen (viacount)          168 non-null    float64
#  88  Suomenlahdentie, pohjoinen (Viacount)          168 non-null    float64
#  89  Tapiola,Lansituulenkuja (Eco-Counter)          25916 non-null  float64
#  90  Turuntie, Rantaradanreitti (Eco-Counter)       7931 non-null   float64
#  91  Vihdintie, Kalajarven itapuoli (Viacount 2)    168 non-null    float64
#  92  Vihdintie, Uusmaki (DSL10)                     13667 non-null  float64
#  93  Ylismaentie,Suurpelto (Eco-Counter)            7923 non-null   float64
# dtypes: Int64(4), bool(1), datetime64[ns](1), float64(84), int64(1), object(3)
# memory usage: 36.6+ MB
