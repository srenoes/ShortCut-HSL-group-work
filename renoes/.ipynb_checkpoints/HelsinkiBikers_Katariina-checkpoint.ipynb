# %% [markdown]
# # HSL - Final Project of cyclists

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#
# Chech file name before execute this command, just in case
#
# dataset: Helsinki cyclists
HKI_bikers = pd.read_excel('Helsingin_pyorailijamaarat.xlsx')
HKI_bikers_apu = pd.read_excel('Helsingin_pyorailijamaarat.xlsx')

# dataset: Espoo cyclists
# ESPOO_bikers = pd.read_excel('Espoon_pyorailijamaarat.xlsx')
# ESPOO_bikerstation = pd.read_excel('Espoo_pyoralaskentapisteiden_sijainnit.xlsx')

# dataset: Vantaa cyclists
# VANTAA_bikers = pd.read_excel('Vantaan_pyorailijamaarat.xlsx')
# VANTAA_bikerstation = pd.read_excel('Vantaa_pyoralaskentapisteiden_sijainnit.xlsx')

# CityBikes = City Bikes are in separate file

# %%
# print out dataset: Helsinki cyclists
HKI_bikers
# Out:
#                   Päivämäärä  Auroransilta  Eteläesplanadi  \
# 0      ke 1 tammi 2014 00:00           NaN             7.0
# 1      ke 1 tammi 2014 01:00           NaN             5.0
# 2      ke 1 tammi 2014 02:00           NaN             2.0
# 3      ke 1 tammi 2014 03:00           NaN             5.0
# 4      ke 1 tammi 2014 04:00           NaN             1.0
# ...                      ...           ...             ...
# 51115  to 31 loka 2019 19:00          24.0            60.0
# 51116  to 31 loka 2019 20:00          32.0            51.0
# 51117  to 31 loka 2019 21:00          21.0            23.0
# 51118  to 31 loka 2019 22:00           8.0            13.0
# 51119  to 31 loka 2019 23:00           3.0            16.0
#
#        Huopalahti (asema)  Kaisaniemi/Eläintarhanlahti  Kaivokatu  \
# 0                     NaN                          1.0        NaN
# 1                     NaN                          3.0        NaN
# 2                     NaN                          3.0        NaN
# 3                     NaN                          2.0        NaN
# 4                     NaN                          4.0        NaN
# ...                   ...                          ...        ...
# 51115                47.0                         46.0      104.0
# 51116                34.0                         39.0       71.0
# 51117                19.0                         13.0       62.0
# 51118                 8.0                          9.0       34.0
# 51119                 5.0                          8.0       15.0
#
#        Kulosaaren silta et.  Kulosaaren silta po.   Kuusisaarentie  \
# 0                       NaN                    NaN             NaN
# 1                       NaN                    NaN             NaN
# 2                       NaN                    NaN             NaN
# 3                       NaN                    NaN             NaN
# 4                       NaN                    NaN             NaN
# ...                     ...                    ...             ...
# 51115                  12.0                   44.0            20.0
# 51116                  14.0                   24.0            12.0
# 51117                   7.0                   18.0            14.0
# 51118                   3.0                   13.0             8.0
# 51119                   1.0                    8.0             3.0
#
#        Käpylä, Pohjoisbaana  ...  Merikannontie  \
# 0                       NaN  ...            NaN
# 1                       NaN  ...            NaN
# 2                       NaN  ...            NaN
# 3                       NaN  ...            NaN
# 4                       NaN  ...            NaN
# ...                     ...  ...            ...
# 51115                   0.0  ...           76.0
# 51116                   0.0  ...           47.0
# 51117                   0.0  ...           37.0
# 51118                   0.0  ...           13.0
# 51119                   0.0  ...            1.0
#
#        Munkkiniemen silta eteläpuoli  Munkkiniemi silta pohjoispuoli  \
# 0                                2.0                             5.0
# 1                                6.0                             5.0
# 2                                1.0                             1.0
# 3                                0.0                             2.0
# 4                                1.0                             1.0
# ...                              ...                             ...
# 51115                           46.0                            18.0
# 51116                           41.0                            27.0
# 51117                           24.0                            16.0
# 51118                           12.0                             8.0
# 51119                            2.0                             2.0
#
#        Heperian puisto/Ooppera  Pitkäsilta itäpuoli  Pitkäsilta länsipuoli  \
# 0                          3.0                  NaN                   11.0
# 1                          1.0                  NaN                    8.0
# 2                          1.0                  NaN                   14.0
# 3                          0.0                  NaN                    7.0
# 4                          1.0                  NaN                    9.0
# ...                        ...                  ...                    ...
# 51115                    110.0                 79.0                   45.0
# 51116                     90.0                 56.0                   41.0
# 51117                     68.0                 44.0                   37.0
# 51118                     26.0                 23.0                    9.0
# 51119                     16.0                 19.0                   10.0
#
#        Lauttasaaren silta pohjoispuoli  Ratapihantie  Viikintie  Baana
# 0                                  NaN           NaN        NaN      8
# 1                                  NaN           NaN        NaN      4
# 2                                  NaN           NaN        NaN     11
# 3                                  NaN           NaN        NaN      3
# 4                                  NaN           NaN        NaN      4
# ...                                ...           ...        ...    ...
# 51115                              0.0          42.0        NaN    111
# 51116                              0.0          39.0        NaN     82
# 51117                              0.0          42.0        NaN     74
# 51118                              0.0           9.0        NaN     33
# 51119                              0.0           7.0        NaN     16
#
# [51120 rows x 21 columns]

# %%
# rename columns' column names, change ä -> a and ö -> o
HKI_bikers = HKI_bikers.rename({'Päivämäärä': 'Date_tmp', 'Eteläesplanadi': 'Etelaesplanadi', 'Kaisaniemi/Eläintarhanlahti': 'Kaisaniemi/Elaintarhanlahti'}, axis=1)
HKI_bikers = HKI_bikers.rename({'Käpylä, Pohjoisbaana': 'Kapyla, Pohjoisbaana', 'Lauttasaaren silta eteläpuoli': 'Lauttasaaren silta etelapuoli'}, axis=1)
HKI_bikers = HKI_bikers.rename({'Munkkiniemen silta eteläpuoli': 'Munkkiniemen silta etelapuoli', 'Pitkäsilta itäpuoli': 'Pitkasilta itapuoli', 'Pitkäsilta länsipuoli': 'Pitkasilta lansipuoli'}, axis=1)
# rename columns' column names from finnish to english
HKI_bikers = HKI_bikers.rename({'Huopalahti (asema)':'Huopalahti (station)', 'Kulosaaren silta et.':'Kulosaari bridge south', 'Kulosaaren silta po.':'Kulosaari bridge north'}, axis=1)
HKI_bikers = HKI_bikers.rename({'Lauttasaaren silta etelapuoli': 'Lauttasaarin bridge south side', 'Munkkiniemen silta etelapuoli': 'Munkkiniemi bridge south side', 'Munkkiniemi silta pohjoispuoli':'Munkkiniemi bridge north side'}, axis=1)
HKI_bikers = HKI_bikers.rename({'Heperian puisto/Ooppera':'Heperia park/Ooppera',' Pitkasilta itapuoli': 'Pitkasilta east side', 'Pitkasilta lansipuoli': 'Pitkasilta west side'}, axis=1)
HKI_bikers = HKI_bikers.rename({'Lauttasaaren silta pohjoispuoli':'Lauttasaari bridge north side'}, axis=1)
HKI_bikers
# Out:
#                     Date_tmp  Auroransilta  Etelaesplanadi  \
# 0      ke 1 tammi 2014 00:00           NaN             7.0
# 1      ke 1 tammi 2014 01:00           NaN             5.0
# 2      ke 1 tammi 2014 02:00           NaN             2.0
# 3      ke 1 tammi 2014 03:00           NaN             5.0
# 4      ke 1 tammi 2014 04:00           NaN             1.0
# ...                      ...           ...             ...
# 51115  to 31 loka 2019 19:00          24.0            60.0
# 51116  to 31 loka 2019 20:00          32.0            51.0
# 51117  to 31 loka 2019 21:00          21.0            23.0
# 51118  to 31 loka 2019 22:00           8.0            13.0
# 51119  to 31 loka 2019 23:00           3.0            16.0
#
#        Huopalahti (station)  Kaisaniemi/Elaintarhanlahti  Kaivokatu  \
# 0                       NaN                          1.0        NaN
# 1                       NaN                          3.0        NaN
# 2                       NaN                          3.0        NaN
# 3                       NaN                          2.0        NaN
# 4                       NaN                          4.0        NaN
# ...                     ...                          ...        ...
# 51115                  47.0                         46.0      104.0
# 51116                  34.0                         39.0       71.0
# 51117                  19.0                         13.0       62.0
# 51118                   8.0                          9.0       34.0
# 51119                   5.0                          8.0       15.0
#
#        Kulosaari bridge south  Kulosaaren silta po.   Kuusisaarentie  \
# 0                         NaN                    NaN             NaN
# 1                         NaN                    NaN             NaN
# 2                         NaN                    NaN             NaN
# 3                         NaN                    NaN             NaN
# 4                         NaN                    NaN             NaN
# ...                       ...                    ...             ...
# 51115                    12.0                   44.0            20.0
# 51116                    14.0                   24.0            12.0
# 51117                     7.0                   18.0            14.0
# 51118                     3.0                   13.0             8.0
# 51119                     1.0                    8.0             3.0
#
#        Kapyla, Pohjoisbaana  ...  Merikannontie  \
# 0                       NaN  ...            NaN
# 1                       NaN  ...            NaN
# 2                       NaN  ...            NaN
# 3                       NaN  ...            NaN
# 4                       NaN  ...            NaN
# ...                     ...  ...            ...
# 51115                   0.0  ...           76.0
# 51116                   0.0  ...           47.0
# 51117                   0.0  ...           37.0
# 51118                   0.0  ...           13.0
# 51119                   0.0  ...            1.0
#
#        Munkkiniemi bridge south side  Munkkiniemi bridge north side  \
# 0                                2.0                            5.0
# 1                                6.0                            5.0
# 2                                1.0                            1.0
# 3                                0.0                            2.0
# 4                                1.0                            1.0
# ...                              ...                            ...
# 51115                           46.0                           18.0
# 51116                           41.0                           27.0
# 51117                           24.0                           16.0
# 51118                           12.0                            8.0
# 51119                            2.0                            2.0
#
#        Heperia park/Ooppera  Pitkasilta itapuoli  Pitkasilta west side  \
# 0                       3.0                  NaN                  11.0
# 1                       1.0                  NaN                   8.0
# 2                       1.0                  NaN                  14.0
# 3                       0.0                  NaN                   7.0
# 4                       1.0                  NaN                   9.0
# ...                     ...                  ...                   ...
# 51115                 110.0                 79.0                  45.0
# 51116                  90.0                 56.0                  41.0
# 51117                  68.0                 44.0                  37.0
# 51118                  26.0                 23.0                   9.0
# 51119                  16.0                 19.0                  10.0
#
#        Lauttasaari bridge north side  Ratapihantie  Viikintie  Baana
# 0                                NaN           NaN        NaN      8
# 1                                NaN           NaN        NaN      4
# 2                                NaN           NaN        NaN     11
# 3                                NaN           NaN        NaN      3
# 4                                NaN           NaN        NaN      4
# ...                              ...           ...        ...    ...
# 51115                            0.0          42.0        NaN    111
# 51116                            0.0          39.0        NaN     82
# 51117                            0.0          42.0        NaN     74
# 51118                            0.0           9.0        NaN     33
# 51119                            0.0           7.0        NaN     16
#
# [51120 rows x 21 columns]

# %%
#
# replace finnish word with english words due to datetime convertion
#
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('tammi', 'Jan')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('helmi', 'Feb')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('maalis', 'Mar')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('huhti', 'Apr')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('touko', 'May')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('kesä', 'Jun')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('heinä', 'Jul')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('elo', 'Aug')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('syys', 'Sep')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('loka', 'Oct')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('marras', 'Nov')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('joulu', 'Dec')

HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('ma', 'Mon')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('ti', 'Tue')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('ke', 'Wed')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('to', 'Thu')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('pe', 'Fri')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('la', 'Sat')
HKI_bikers.Date_tmp = HKI_bikers.Date_tmp.str.replace('su', 'Sun')
# print put result
HKI_bikers
# Out:
#                     Date_tmp  Auroransilta  Etelaesplanadi  \
# 0       Wed 1 Jan 2014 00:00           NaN             7.0
# 1       Wed 1 Jan 2014 01:00           NaN             5.0
# 2       Wed 1 Jan 2014 02:00           NaN             2.0
# 3       Wed 1 Jan 2014 03:00           NaN             5.0
# 4       Wed 1 Jan 2014 04:00           NaN             1.0
# ...                      ...           ...             ...
# 51115  Thu 31 Oct 2019 19:00          24.0            60.0
# 51116  Thu 31 Oct 2019 20:00          32.0            51.0
# 51117  Thu 31 Oct 2019 21:00          21.0            23.0
# 51118  Thu 31 Oct 2019 22:00           8.0            13.0
# 51119  Thu 31 Oct 2019 23:00           3.0            16.0
#
#        Huopalahti (station)  Kaisaniemi/Elaintarhanlahti  Kaivokatu  \
# 0                       NaN                          1.0        NaN
# 1                       NaN                          3.0        NaN
# 2                       NaN                          3.0        NaN
# 3                       NaN                          2.0        NaN
# 4                       NaN                          4.0        NaN
# ...                     ...                          ...        ...
# 51115                  47.0                         46.0      104.0
# 51116                  34.0                         39.0       71.0
# 51117                  19.0                         13.0       62.0
# 51118                   8.0                          9.0       34.0
# 51119                   5.0                          8.0       15.0
#
#        Kulosaari bridge south  Kulosaaren silta po.   Kuusisaarentie  \
# 0                         NaN                    NaN             NaN
# 1                         NaN                    NaN             NaN
# 2                         NaN                    NaN             NaN
# 3                         NaN                    NaN             NaN
# 4                         NaN                    NaN             NaN
# ...                       ...                    ...             ...
# 51115                    12.0                   44.0            20.0
# 51116                    14.0                   24.0            12.0
# 51117                     7.0                   18.0            14.0
# 51118                     3.0                   13.0             8.0
# 51119                     1.0                    8.0             3.0
#
#        Kapyla, Pohjoisbaana  ...  Merikannontie  \
# 0                       NaN  ...            NaN
# 1                       NaN  ...            NaN
# 2                       NaN  ...            NaN
# 3                       NaN  ...            NaN
# 4                       NaN  ...            NaN
# ...                     ...  ...            ...
# 51115                   0.0  ...           76.0
# 51116                   0.0  ...           47.0
# 51117                   0.0  ...           37.0
# 51118                   0.0  ...           13.0
# 51119                   0.0  ...            1.0
#
#        Munkkiniemi bridge south side  Munkkiniemi bridge north side  \
# 0                                2.0                            5.0
# 1                                6.0                            5.0
# 2                                1.0                            1.0
# 3                                0.0                            2.0
# 4                                1.0                            1.0
# ...                              ...                            ...
# 51115                           46.0                           18.0
# 51116                           41.0                           27.0
# 51117                           24.0                           16.0
# 51118                           12.0                            8.0
# 51119                            2.0                            2.0
#
#        Heperia park/Ooppera  Pitkasilta itapuoli  Pitkasilta west side  \
# 0                       3.0                  NaN                  11.0
# 1                       1.0                  NaN                   8.0
# 2                       1.0                  NaN                  14.0
# 3                       0.0                  NaN                   7.0
# 4                       1.0                  NaN                   9.0
# ...                     ...                  ...                   ...
# 51115                 110.0                 79.0                  45.0
# 51116                  90.0                 56.0                  41.0
# 51117                  68.0                 44.0                  37.0
# 51118                  26.0                 23.0                   9.0
# 51119                  16.0                 19.0                  10.0
#
#        Lauttasaari bridge north side  Ratapihantie  Viikintie  Baana
# 0                                NaN           NaN        NaN      8
# 1                                NaN           NaN        NaN      4
# 2                                NaN           NaN        NaN     11
# 3                                NaN           NaN        NaN      3
# 4                                NaN           NaN        NaN      4
# ...                              ...           ...        ...    ...
# 51115                            0.0          42.0        NaN    111
# 51116                            0.0          39.0        NaN     82
# 51117                            0.0          42.0        NaN     74
# 51118                            0.0           9.0        NaN     33
# 51119                            0.0           7.0        NaN     16
#
# [51120 rows x 21 columns]

# %%
#
# here is weekday and datetime split to each own columns
#
weekday = HKI_bikers["Date_tmp"].str.split(" ", n = 1, expand = True)
HKI_bikers.insert(0, 'Weekday', weekday[0])
HKI_bikers.insert(1, 'Date', weekday[1])
HKI_bikers = HKI_bikers.drop(['Date_tmp'], axis=1)
HKI_bikers
# Out:
#       Weekday               Date  Auroransilta  Etelaesplanadi  \
# 0         Wed   1 Jan 2014 00:00           NaN             7.0
# 1         Wed   1 Jan 2014 01:00           NaN             5.0
# 2         Wed   1 Jan 2014 02:00           NaN             2.0
# 3         Wed   1 Jan 2014 03:00           NaN             5.0
# 4         Wed   1 Jan 2014 04:00           NaN             1.0
# ...       ...                ...           ...             ...
# 51115     Thu  31 Oct 2019 19:00          24.0            60.0
# 51116     Thu  31 Oct 2019 20:00          32.0            51.0
# 51117     Thu  31 Oct 2019 21:00          21.0            23.0
# 51118     Thu  31 Oct 2019 22:00           8.0            13.0
# 51119     Thu  31 Oct 2019 23:00           3.0            16.0
#
#        Huopalahti (station)  Kaisaniemi/Elaintarhanlahti  Kaivokatu  \
# 0                       NaN                          1.0        NaN
# 1                       NaN                          3.0        NaN
# 2                       NaN                          3.0        NaN
# 3                       NaN                          2.0        NaN
# 4                       NaN                          4.0        NaN
# ...                     ...                          ...        ...
# 51115                  47.0                         46.0      104.0
# 51116                  34.0                         39.0       71.0
# 51117                  19.0                         13.0       62.0
# 51118                   8.0                          9.0       34.0
# 51119                   5.0                          8.0       15.0
#
#        Kulosaari bridge south  Kulosaaren silta po.   Kuusisaarentie  ...  \
# 0                         NaN                    NaN             NaN  ...
# 1                         NaN                    NaN             NaN  ...
# 2                         NaN                    NaN             NaN  ...
# 3                         NaN                    NaN             NaN  ...
# 4                         NaN                    NaN             NaN  ...
# ...                       ...                    ...             ...  ...
# 51115                    12.0                   44.0            20.0  ...
# 51116                    14.0                   24.0            12.0  ...
# 51117                     7.0                   18.0            14.0  ...
# 51118                     3.0                   13.0             8.0  ...
# 51119                     1.0                    8.0             3.0  ...
#
#        Merikannontie  Munkkiniemi bridge south side  \
# 0                NaN                            2.0
# 1                NaN                            6.0
# 2                NaN                            1.0
# 3                NaN                            0.0
# 4                NaN                            1.0
# ...              ...                            ...
# 51115           76.0                           46.0
# 51116           47.0                           41.0
# 51117           37.0                           24.0
# 51118           13.0                           12.0
# 51119            1.0                            2.0
#
#        Munkkiniemi bridge north side  Heperia park/Ooppera  \
# 0                                5.0                   3.0
# 1                                5.0                   1.0
# 2                                1.0                   1.0
# 3                                2.0                   0.0
# 4                                1.0                   1.0
# ...                              ...                   ...
# 51115                           18.0                 110.0
# 51116                           27.0                  90.0
# 51117                           16.0                  68.0
# 51118                            8.0                  26.0
# 51119                            2.0                  16.0
#
#        Pitkasilta itapuoli  Pitkasilta west side  \
# 0                      NaN                  11.0
# 1                      NaN                   8.0
# 2                      NaN                  14.0
# 3                      NaN                   7.0
# 4                      NaN                   9.0
# ...                    ...                   ...
# 51115                 79.0                  45.0
# 51116                 56.0                  41.0
# 51117                 44.0                  37.0
# 51118                 23.0                   9.0
# 51119                 19.0                  10.0
#
#        Lauttasaari bridge north side  Ratapihantie  Viikintie  Baana
# 0                                NaN           NaN        NaN      8
# 1                                NaN           NaN        NaN      4
# 2                                NaN           NaN        NaN     11
# 3                                NaN           NaN        NaN      3
# 4                                NaN           NaN        NaN      4
# ...                              ...           ...        ...    ...
# 51115                            0.0          42.0        NaN    111
# 51116                            0.0          39.0        NaN     82
# 51117                            0.0          42.0        NaN     74
# 51118                            0.0           9.0        NaN     33
# 51119                            0.0           7.0        NaN     16
#
# [51120 rows x 22 columns]

# %%
# Change date and time to datatime type
HKI_bikers.Date = pd.to_datetime(HKI_bikers.Date, format='%d %b %Y %H:%M', errors='coerce')
HKI_bikers
# Out:
#       Weekday                Date  Auroransilta  Etelaesplanadi  \
# 0         Wed 2014-01-01 00:00:00           NaN             7.0
# 1         Wed 2014-01-01 01:00:00           NaN             5.0
# 2         Wed 2014-01-01 02:00:00           NaN             2.0
# 3         Wed 2014-01-01 03:00:00           NaN             5.0
# 4         Wed 2014-01-01 04:00:00           NaN             1.0
# ...       ...                 ...           ...             ...
# 51115     Thu 2019-10-31 19:00:00          24.0            60.0
# 51116     Thu 2019-10-31 20:00:00          32.0            51.0
# 51117     Thu 2019-10-31 21:00:00          21.0            23.0
# 51118     Thu 2019-10-31 22:00:00           8.0            13.0
# 51119     Thu 2019-10-31 23:00:00           3.0            16.0
#
#        Huopalahti (station)  Kaisaniemi/Elaintarhanlahti  Kaivokatu  \
# 0                       NaN                          1.0        NaN
# 1                       NaN                          3.0        NaN
# 2                       NaN                          3.0        NaN
# 3                       NaN                          2.0        NaN
# 4                       NaN                          4.0        NaN
# ...                     ...                          ...        ...
# 51115                  47.0                         46.0      104.0
# 51116                  34.0                         39.0       71.0
# 51117                  19.0                         13.0       62.0
# 51118                   8.0                          9.0       34.0
# 51119                   5.0                          8.0       15.0
#
#        Kulosaari bridge south  Kulosaaren silta po.   Kuusisaarentie  ...  \
# 0                         NaN                    NaN             NaN  ...
# 1                         NaN                    NaN             NaN  ...
# 2                         NaN                    NaN             NaN  ...
# 3                         NaN                    NaN             NaN  ...
# 4                         NaN                    NaN             NaN  ...
# ...                       ...                    ...             ...  ...
# 51115                    12.0                   44.0            20.0  ...
# 51116                    14.0                   24.0            12.0  ...
# 51117                     7.0                   18.0            14.0  ...
# 51118                     3.0                   13.0             8.0  ...
# 51119                     1.0                    8.0             3.0  ...
#
#        Merikannontie  Munkkiniemi bridge south side  \
# 0                NaN                            2.0
# 1                NaN                            6.0
# 2                NaN                            1.0
# 3                NaN                            0.0
# 4                NaN                            1.0
# ...              ...                            ...
# 51115           76.0                           46.0
# 51116           47.0                           41.0
# 51117           37.0                           24.0
# 51118           13.0                           12.0
# 51119            1.0                            2.0
#
#        Munkkiniemi bridge north side  Heperia park/Ooppera  \
# 0                                5.0                   3.0
# 1                                5.0                   1.0
# 2                                1.0                   1.0
# 3                                2.0                   0.0
# 4                                1.0                   1.0
# ...                              ...                   ...
# 51115                           18.0                 110.0
# 51116                           27.0                  90.0
# 51117                           16.0                  68.0
# 51118                            8.0                  26.0
# 51119                            2.0                  16.0
#
#        Pitkasilta itapuoli  Pitkasilta west side  \
# 0                      NaN                  11.0
# 1                      NaN                   8.0
# 2                      NaN                  14.0
# 3                      NaN                   7.0
# 4                      NaN                   9.0
# ...                    ...                   ...
# 51115                 79.0                  45.0
# 51116                 56.0                  41.0
# 51117                 44.0                  37.0
# 51118                 23.0                   9.0
# 51119                 19.0                  10.0
#
#        Lauttasaari bridge north side  Ratapihantie  Viikintie  Baana
# 0                                NaN           NaN        NaN      8
# 1                                NaN           NaN        NaN      4
# 2                                NaN           NaN        NaN     11
# 3                                NaN           NaN        NaN      3
# 4                                NaN           NaN        NaN      4
# ...                              ...           ...        ...    ...
# 51115                            0.0          42.0        NaN    111
# 51116                            0.0          39.0        NaN     82
# 51117                            0.0          42.0        NaN     74
# 51118                            0.0           9.0        NaN     33
# 51119                            0.0           7.0        NaN     16
#
# [51120 rows x 22 columns]

# %% [markdown]
# ### from this onwards it is up to you if you want to use these

# %%
# split date and time to two different columns, this command change value to string
HKI_bikers.insert(2, 'Time', HKI_bikers.Date.dt.strftime('%H:%M:%S'))
HKI_bikers.Date = HKI_bikers.Date.dt.strftime('%Y-%m-%d')
# change date (paivamaara) back datetime -value
HKI_bikers.Date = pd.to_datetime(HKI_bikers.Date, format='%Y-%m-%d', errors='coerce')
HKI_bikers
# Out:
#       Weekday       Date      Time  Auroransilta  Etelaesplanadi  \
# 0         Wed 2014-01-01  00:00:00           NaN             7.0
# 1         Wed 2014-01-01  01:00:00           NaN             5.0
# 2         Wed 2014-01-01  02:00:00           NaN             2.0
# 3         Wed 2014-01-01  03:00:00           NaN             5.0
# 4         Wed 2014-01-01  04:00:00           NaN             1.0
# ...       ...        ...       ...           ...             ...
# 51115     Thu 2019-10-31  19:00:00          24.0            60.0
# 51116     Thu 2019-10-31  20:00:00          32.0            51.0
# 51117     Thu 2019-10-31  21:00:00          21.0            23.0
# 51118     Thu 2019-10-31  22:00:00           8.0            13.0
# 51119     Thu 2019-10-31  23:00:00           3.0            16.0
#
#        Huopalahti (station)  Kaisaniemi/Elaintarhanlahti  Kaivokatu  \
# 0                       NaN                          1.0        NaN
# 1                       NaN                          3.0        NaN
# 2                       NaN                          3.0        NaN
# 3                       NaN                          2.0        NaN
# 4                       NaN                          4.0        NaN
# ...                     ...                          ...        ...
# 51115                  47.0                         46.0      104.0
# 51116                  34.0                         39.0       71.0
# 51117                  19.0                         13.0       62.0
# 51118                   8.0                          9.0       34.0
# 51119                   5.0                          8.0       15.0
#
#        Kulosaari bridge south  Kulosaaren silta po.   ...  Merikannontie  \
# 0                         NaN                    NaN  ...            NaN
# 1                         NaN                    NaN  ...            NaN
# 2                         NaN                    NaN  ...            NaN
# 3                         NaN                    NaN  ...            NaN
# 4                         NaN                    NaN  ...            NaN
# ...                       ...                    ...  ...            ...
# 51115                    12.0                   44.0  ...           76.0
# 51116                    14.0                   24.0  ...           47.0
# 51117                     7.0                   18.0  ...           37.0
# 51118                     3.0                   13.0  ...           13.0
# 51119                     1.0                    8.0  ...            1.0
#
#        Munkkiniemi bridge south side  Munkkiniemi bridge north side  \
# 0                                2.0                            5.0
# 1                                6.0                            5.0
# 2                                1.0                            1.0
# 3                                0.0                            2.0
# 4                                1.0                            1.0
# ...                              ...                            ...
# 51115                           46.0                           18.0
# 51116                           41.0                           27.0
# 51117                           24.0                           16.0
# 51118                           12.0                            8.0
# 51119                            2.0                            2.0
#
#        Heperia park/Ooppera  Pitkasilta itapuoli  Pitkasilta west side  \
# 0                       3.0                  NaN                  11.0
# 1                       1.0                  NaN                   8.0
# 2                       1.0                  NaN                  14.0
# 3                       0.0                  NaN                   7.0
# 4                       1.0                  NaN                   9.0
# ...                     ...                  ...                   ...
# 51115                 110.0                 79.0                  45.0
# 51116                  90.0                 56.0                  41.0
# 51117                  68.0                 44.0                  37.0
# 51118                  26.0                 23.0                   9.0
# 51119                  16.0                 19.0                  10.0
#
#        Lauttasaari bridge north side  Ratapihantie  Viikintie  Baana
# 0                                NaN           NaN        NaN      8
# 1                                NaN           NaN        NaN      4
# 2                                NaN           NaN        NaN     11
# 3                                NaN           NaN        NaN      3
# 4                                NaN           NaN        NaN      4
# ...                              ...           ...        ...    ...
# 51115                            0.0          42.0        NaN    111
# 51116                            0.0          39.0        NaN     82
# 51117                            0.0          42.0        NaN     74
# 51118                            0.0           9.0        NaN     33
# 51119                            0.0           7.0        NaN     16
#
# [51120 rows x 23 columns]

# %% [markdown]
# #### changing actual clock time to numeric value is tricky and lets do this if it is needed. So time is string for now.

# %%
# print out dataset information
HKI_bikers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51120 entries, 0 to 51119
# Data columns (total 23 columns):
# Weekday                           51120 non-null object
# Date                              51120 non-null datetime64[ns]
# Time                              51120 non-null object
# Auroransilta                      17306 non-null float64
# Etelaesplanadi                    50450 non-null float64
# Huopalahti (station)              39335 non-null float64
# Kaisaniemi/Elaintarhanlahti       51118 non-null float64
# Kaivokatu                         17304 non-null float64
# Kulosaari bridge south            39335 non-null float64
# Kulosaaren silta po.              39335 non-null float64
# Kuusisaarentie                    39335 non-null float64
# Kapyla, Pohjoisbaana              18462 non-null float64
# Lauttasaarin bridge south side    44230 non-null float64
# Merikannontie                     44230 non-null float64
# Munkkiniemi bridge south side     50815 non-null float64
# Munkkiniemi bridge north side     51118 non-null float64
# Heperia park/Ooppera              49942 non-null float64
# Pitkasilta itapuoli               44230 non-null float64
# Pitkasilta west side              51118 non-null float64
# Lauttasaari bridge north side     40134 non-null float64
# Ratapihantie                      39335 non-null float64
# Viikintie                         10510 non-null float64
# Baana                             51120 non-null int64
# dtypes: datetime64[ns](1), float64(19), int64(1), object(2)
# memory usage: 9.0+ MB
