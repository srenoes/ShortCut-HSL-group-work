# %%
import pandas as pd
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %%
ALL_Bikers=pd.read_csv('All_bikers.csv')
ALL_Bikers.plot(y="nData",x="Date", figsize=[10,10])
plt.show()
